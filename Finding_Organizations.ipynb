# %%
import rdflib
import pyshacl

# %% [markdown]
# ### Importing the RDF Graph

# %%
q = rdflib.Graph()
q.parse(r"C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_Tests/Hydrogen_Refined_Graph.ttl")
query = """SELECT ?s ?p ?o WHERE {?s ?p ?o .}"""
results = q.query(query)
for result in results:
    print(result)
# Out:
# (rdflib.term.URIRef('http://fraunhofer.de/data/Channel_10'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Bloom'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Perovskites_crystals'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_technology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Energy_Department'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/SoCalGas'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Post_Ammonia_Fuel_Cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Reconversion'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Thiebault_Paquet'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_trains'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Train'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Toyota_Motor_Corporation'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hydrogen_fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Maanshan_City'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_Cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('https://www.hydrogenfuelnews.com/hydrogen-fueling-infrastructure/8541312/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_train'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Australia'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Compression'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Green_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Conversion'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/ketoximes'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/TME'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cell'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_production'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/products'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_projects'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Daimler_Truck_Fuel_Cell_GmbH__AMPERSAND__Co_KG'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Truck'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/H2O_Molecules'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Beijing'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/the_Suiso_Frontier'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_technology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/News_Engineered_Products'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://article.wn.com/view/2016/05/25/Hydrogen_Fuel_Cell_Bus_Hits_OC_Streets_OCTA_Orange_County_Tr/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/European_Clean_Hydrogen_Alliance'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Antiseptic_Mouth_Wash'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/research/_media_organizations'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/ZeroAvia'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/FuelCellsWorks'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://www.myjournals.org/index_php_nr_393867'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Climate_Action_Champions'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('https://www.marketscreener.com/quote/stock/DAIMLER-AG-436541/news/Daimler-Volvo-plan-hydrogen-fuel-cell-production-in-Europe-in-2025-33105649/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/TME'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('https://fuelcellsworks.com/subscribers/swk-opts-for-green-hydrogen-production-in-cooperation-with-the-swk-e²-institute-of-the-niederrhein-university-of-applied-sciences/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Daimler_AG'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_Cell'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hydrogen_and_Fuel_Cell_Technologies'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/zero_emission_technology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/solid_oxide_fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/H2'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/methanol_fuel_cell'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Talgo_Vittal_One'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/new_hydrogen_vehicle'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hydrogen_Infrastructure'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/a_product_that_gamers_can_enjoy_as_intended'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Twitter'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Australia'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/solid_oxide_fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Reconversion'))
# (rdflib.term.URIRef('http://southafrica.cleantechopen.org/2016/05/20/sharks-electric-field-sixth-sense-could-inspire-better-fuel-cells/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/discovery'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/ECH2A'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Tuesday'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/a_new_technology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel_cell_system'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cells_are'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/clean_technology_revolution'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Road'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_train'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/CrystEngComm'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/applications'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hydrogen_plane'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Dedicated_Fuel_Cell_System'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Stellantis'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Ref__XX'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cell_system'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/proton_conducting_fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cell_vehicles'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Reconversion'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_and_fuel_cell_technologies'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Orange_County_Transportation_Authority'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Mobile'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Matthias_Jurytko'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_in'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/a_six_seater_propeller_plane_powered_by_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Aircraft'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_technology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hydrogen_fuel_cars'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Car'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_trains'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/decarbonising_road_transport'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Mobile'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Beiqi_Foton_Motor'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fossil_fuel'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#FossilFuel'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/methanol_fuel_cell'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#EthanolFuelCell'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_Cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Volvo'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/vehicles'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/ACWA_Power'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Lhyfe'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Inabe_Plant'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Volvo_Group'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_Cell_Technologies'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Ammonia_Fuel_Cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/H2'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/solar'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('https://www.hyundainews.com/en-us/releases/3217'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_and_fuel'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_transportation'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Australia'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Franco_German'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Tuesday'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Talgo'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cells_are'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Activision'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/High_Pressure_Hydrogen_Tanks'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Toyota'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Doritos'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Mads_Friis_Jensen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_trains'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/James_Frimen_/_Friday'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Ref__XX'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Toyoda_Gosei'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hydrogen_plane'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Aircraft'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/2020'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cell_electric_vehicles'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Road'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hydrogen_Cars'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Car'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/AUVSI'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/catalyst'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_cell_power_pack'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/governments_and_businesses'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/_QUOTATION_OR_APOSTROPHE_green_QUOTATION_OR_APOSTROPHE__hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_projects'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://schema.org/Project'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Kawasaki_Heavy_Industries'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_vehicle_fleet'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Road'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Beijing'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hyundai'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://www.virtual-strategy.com/2016/05/25/dni_metals_inc_appoints_lithium_ion_battery_and_fuel_cell_experts_board_directors'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Wind_Hunter_Project'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://schema.org/Project'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Toyoda_Gosei_Co___COMMA__Ltd'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Amazon'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('https://fuelcellsworks.com/news/friday-fallback-story-storengy-and-gazelenergie-join-forces-coal-fired-power-stations-to-be-converted-to-hydrogen/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/DOI'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/H2O2'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Video'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Blue_World_Technologies'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/next_generation'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Green_Hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fortescue_Metals_Group'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel_cell_system'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/IEEE_Spectrum'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/The_European_Union'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/solar'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Vanguard'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Ammonia_Fuel_Cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#AmmoniaFuelCell'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Renewable_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Volvo_AB'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/European_Union'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel_cell_system'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Wind_Hunter_Project'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/produce'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/methanol'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/DNI'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_trains'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/technology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Advance_Article'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#RegionalTruck'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/contribute_to_the_development_of_zero_carbon_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Car'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/product'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/railway_lines'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Train'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/H2O2'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('https://www.mamamia.com.au/h20-just-add-water-cast-now/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hyundai_Motor_Group'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/multi_use_passenger_vehicles'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Road'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Japan'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel__COMMA_'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel_cell'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Green_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/NJC'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Daimler_Truck_Fuel_Cell_GmbH__AMPERSAND__Co_KG'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_cell_power_pack'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/UK'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/OCTA'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/mouth_wash'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/solid_oxide_fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#SolidOxideFuelCell'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_Cell_Polarized'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/transportation_is'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Mobile'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/natural_gas'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/highly_compressed_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/TME'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/carandbike_com'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Car'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/batteries'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/a_new_technology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/the__A_WITH_CIRCUMFLEX__EURO__OE__European_Clean_Hydrogen_Alliance'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/testing_and_vaccination_strategy'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Toyota'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_and'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cell_electric_vehicles'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hydrogen_Peroxide'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Breakthrough_Energy_Ventures'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/aircraft'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Toyota'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Advance_Article'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Daimler_Truck_AG'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Lithium_Ion_Battery'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Featured_Company_Featured_Company_DNI_Metals_Inc'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/LONDON'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/H2O2'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Antiseptic_Mouth_Wash'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('https://autotechinsight.ihsmarkit.com/news/5260191/mahle_opens_new_test_center_in_germany_for_fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/proton_exchange_membranes'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Membrane'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/News_Engineered_Products'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_Cell_Vehicles'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Road'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/HyET_Hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/products'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Zhao'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Reuters'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/renewable_energy'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_train'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('https://pubs.rsc.org/en/content/articlelanding/2020/ce/d0ce01311k'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/green_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/mining'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# ...
# (rdflib.term.URIRef('http://fraunhofer.de/data/applications'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Application'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Lithium_Ion_Battery_and_Fuel_Cell'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/GLOBE_NEWSWIRE'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Vanguard'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/HTWO'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel_cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/technology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('https://www.forbes.com/sites/mitchwallace/2020/12/18/i-got-one-of-only-77-limited-cyberpunk-2077-doritos-fuel-cells-and-its-insanely-cool/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Talgo'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/zero_emission_technology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/SOFC4Maritime'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#SolidOxideFuelCell'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fuel_cell_modules'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Blue_World_Technologies'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_tank'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/a_fuel_cell_electric'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Ammonia'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/OCTA'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Toyoda_Gosei'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/UK'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/aircraft'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Aircraft'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Zhao'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://www.4-traders.com/news/China-Petrochemical-Sinopec-rsquo-s-diesel-hydrogenation-technology-wins-bidding-of-Brunei-project--22414754/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/vehicles'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/renewable_energy'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_cell_power_pack'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Reconversion'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Dedicated_Fuel_Cell_System'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hyundai'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/DOI'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/green_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fukushima'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('https://smallnews.in/renewables/2020/12/01/mol-joins-wind-hunter-project-for-combination-of-sails-and-fuel-cells-on-ships/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/CEC'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/cyano_bridged_coordination_polymers'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Daimler_Truck_Fuel_Cell_GmbH__AMPERSAND__Co_KG'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Mads_Friis_Jensen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Green_Hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/POSTECH_University'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Research'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Talgo_Vittal_One'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Deep_Sea_Shipping'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Marine'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Toyota_Motor_Europe'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/H20'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/1st_Hydrogen_NEXO_Vehicle'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Road'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel__COMMA_'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Masamichi_Okada'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Renewable_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/ORR'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Volvo_AB'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_Cell_Business'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/ammonia'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/mobility'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/product'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/water_when_it_burns'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_production'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Blue_World_Technologies'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/TME'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inTesting'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/aircraft'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/European'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inProduction'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/hydrogen_fuel_cell'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://phoenixsun.co.za/34773/tuesday-life-hack-5-uses-for-hydrogen-peroxide/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/European_Clean_Hydrogen_Alliance'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('https://archive.org/details/NearFuturePropulsionExtras_0_5_3'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Hyundai_Motor_Group'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Researcher'))
# (rdflib.term.URIRef('https://fuelcellsworks.com/news/dr-matthias-jurytko-takes-over-the-management-of-the-fuel-cell-joint-venture-cellcentric/'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/dc/terms/BibliographicResource'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/fossil_fuel'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/inResearch'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Fuel_Cell_Polarized'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Zhao'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Reuters'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Customer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Volvo'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Manufacturer'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/Plug_Power_Fuel_Cells'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Product'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/University'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://fraunhofer.de/MarketActivities/Supplier'))
# (rdflib.term.URIRef('http://fraunhofer.de/data/carbon_free_hydrogen'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/neunsinger/ontologies/2022/2.0/HydrogenOntology#Car'))

# %% [markdown]
# ### get_delimiter returns the part of the subject, predicate and object after the last special character in the URL, i.e., '/' or '#'

# %%
def get_delimiter(url):
    if '#' in url:
        delimiter = '#'
    else:
        delimiter = '/'
    return delimiter

# %% [markdown]
# # Firstly, we create a list temporary_list_of_triples which in turn contains lists containing subject, predicate, and object of each triple. Then, we create a dictionary case_list which contains each subject as the key value and all the predicates and objects related to that specific subject in a list of dictionaries. The format is to be understood as: {subject1:[{predicate1:object1},{predicate2:object2}.....],subject2:[{predicate1:object1},{predicate2:object2}].....}.

# %%
import itertools
temporary_list_of_triples = []
for row in results:
    subject = str(row[0]).split(get_delimiter(str(row[0])))[-1] # Getting the subject from a triple
    predicate = str(row[1]).split(get_delimiter(str(row[1])))[-1] #Getting the predicate from a triple
    object = str(row[2]).split(get_delimiter(str(row[2])))[-1] # Getting the object from a triple
    temporary_list_of_triples.append([str(subject),str(predicate),str(object)]) # A list of lists containing subjects,predicates,objects



subjects = [data[0] for data in temporary_list_of_triples] #all subjects in temporary_list_of_triples
subjects = set(subjects) #we find out all the unique subjects
empty_dict = dict(zip(subjects, [None]*len(subjects)))#we set empty_dct as {subject1:None,subject2:None...}
case_list = {}
for name, items in itertools.product(empty_dict, temporary_list_of_triples):
    if ((len(items[0])>=1) & (items[0] == name)):#This was necessary, as often there was nothing left after the initial filteration using get_url(see above). We consider only subjects having text after the last '/' or '#'
        if(items[0][0].isupper()):#By inspecting the RDF Graph, I found a rule that was satisfactory to filter out organizations: All organization names started with capital letters. So used this filtering.
            temp = {items[1]:items[2]}#Creating the sub dictionary {predicate:object}
            if name in case_list:
                case_list[name].append(temp)#if name already present in case_list,append to the list of dictionaries for a specific subject
            else:
                case_list[name] = [temp]#else, set subject:[{predicate1:object1}] 
print(case_list)
# Out:
# {'Advance_Article': [{'type': 'RegionalTruck'}, {'type': 'Supplier'}, {'type': 'inProduction'}, {'type': 'inTesting'}], 'DOI': [{'type': 'Supplier'}, {'type': 'Customer'}, {'type': 'Manufacturer'}, {'type': 'Researcher'}], 'Switch_to_Hydrogen_Buses': [{'type': 'Bus'}], 'CrystEngComm': [{'type': 'Supplier'}, {'type': 'Manufacturer'}, {'type': 'Researcher'}], 'ALICE': [{'type': 'Manufacturer'}, {'type': 'Supplier'}], 'High_Pressure_Hydrogen_Tanks': [{'type': 'Researcher'}, {'type': 'Supplier'}, {'type': 'Manufacturer'}], 'Fukushima_Prefecture': [{'type': 'Researcher'}], 'Lithium_Ion_Battery_and_Fuel_Cell': [{'type': 'inResearch'}, {'type': 'LithiumBattery'}, {'type': 'Product'}, {'type': 'Battery'}, {'type': 'inProduction'}, {'type': 'Reconversion'}, {'type': 'inTesting'}], 'CAF': [{'type': 'Researcher'}], 'Featured_Company_Featured_Company_DNI_Metals_Inc': [{'type': 'Researcher'}, {'type': 'RegisteredOrganization'}], 'ACWA_Power': [{'type': 'Researcher'}, {'type': 'Supplier'}, {'type': 'Manufacturer'}, {'type': 'Customer'}], 'Toyoda_Gosei': [{'type': 'Supplier'}, {'type': 'Manufacturer'}, {'type': 'Customer'}, {'type': 'Researcher'}], 'Methanol_fuel_cell_system': [{'type': 'Reconversion'}, {'type': 'MethanolFuelCell'}, {'type': 'EthanolFuelCell'}, {'type': 'Product'}], 'China': [{'type': 'Supplier'}, {'type': 'Customer'}, {'type': 'Manufacturer'}, {'type': 'inProduction'}, {'type': 'Researcher'}], 'Powertrain_Daimler_Trucks_division': [{'type': 'Truck'}, {'type': 'Train'}], 'Ref__XX': [{'type': 'inTesting'}, {'type': 'inProduction'}, {'type': 'inResearch'}], 'Vanguard': [{'type': 'Manufacturer'}, {'type': 'Researcher'}, {'type': 'Supplier'}, {'type': 'Customer'}], 'Industry_News': [{'type': 'Researcher'}, {'type': 'Supplier'}, {'type': 'Customer'}], 'Climate_Pledge_Fund': [{'type': 'inProduction'}, {'type': 'inResearch'}], 'ECH2A': [{'type': 'Manufacturer'}, {'type': 'Researcher'}, {'type': 'Supplier'}], 'Franco_German': [{'type': 'Customer'}], 'FuelCellsWorks': [{'type': 'Supplier'}, {'type': 'inResearch'}, {'type': 'Customer'}, {'type': 'Manufacturer'}, {'type': 'inProduction'}, {'type': 'Researcher'}], 'UK': [{'type': 'Researcher'}, {'type': 'Supplier'}, {'type': 'Customer'}, {'type': 'Manufacturer'}], 'Hydrogen__AMPERSAND__Fuel_Cells': [{'type': 'Researcher'}, {'type': 'Supplier'}], 'Org': [{'type': 'Supplier'}], 'Position_yourself_for_advantage': [{'type': 'RegionalTruck'}], 'Fuel_Cells': [{'type': 'inResearch'}, {'type': 'Supplier'}, {'type': 'inProduction'}, {'type': 'Reconversion'}, {'type': 'inTesting'}, {'type': 'Product'}, {'type': 'Researcher'}], 'News_Engineered_Products': [{'type': 'Researcher'}, {'type': 'Supplier'}], 'Toyota': [{'type': 'Manufacturer'}, {'type': 'inProduction'}, {'type': 'Customer'}, {'type': 'Researcher'}, {'type': 'inResearch'}, {'type': 'Supplier'}], 'Beijing': [{'type': 'Manufacturer'}, {'type': 'Customer'}, {'type': 'Researcher'}, {'type': 'Supplier'}], 'Hydrogen_Fuel_Cell': [{'type': 'inProduction'}, {'type': 'Researcher'}, {'type': 'Reconversion'}, {'type': 'inTesting'}, {'type': 'Product'}, {'type': 'inResearch'}], 'Twitter': [{'type': 'Researcher'}, {'type': 'inTesting'}, {'type': 'inProduction'}], 'Avions_Mauboussin': [{'type': 'Supplier'}], 'The_European_Union': [{'type': 'Researcher'}, {'type': 'Supplier'}, {'type': 'Customer'}, {'type': 'Manufacturer'}], 'Hydrogen_Fuel_Cell_Buses': [{'type': 'Reconversion'}, {'type': 'Product'}, {'type': 'Bus'}, {'type': 'inProduction'}], 'Deep_Sea_Shipping': [{'type': 'Marine'}], 'Hydrogen_Cars': [{'type': 'Car'}], 'POSTECH_University': [{'type': 'Research'}], 'Fuel_Cell_Polarized': [{'type': 'inResearch'}, {'type': 'inProduction'}, {'type': 'Reconversion'}, {'type': 'inTesting'}, {'type': 'Product'}], 'Lhyfe': [{'type': 'Supplier'}, {'type': 'Customer'}, {'type': 'Manufacturer'}, {'type': 'Researcher'}], 'Spanish_utility_Iberdrola': [{'type': 'Customer'}, {'type': 'Supplier'}], 'San_Francisco': [{'type': 'Supplier'}, {'type': 'Customer'}, {'type': ...

# %% [markdown]
# ### The below code now groups together common predicates for a specific sibject together, ex - 'Daimler_Truck_Fuel_Cell': for 'Daimler_Truck_Fuel_Cell': [{'type': 'Customer'}, {'type': 'Supplier'}....], the below code will result in 'Daimler_Truck_Fuel_Cell': 'type':'Customer,Supplier'.

# %%
import pandas as pd
rows = []
for key, values in case_list.items():
    row = {'Entity': key}
    for item in values:
        for k, v in item.items():
            
            row[k] = row.get(k, '') + ',' + v if row.get(k, '') else v
    rows.append(row)
    

df = pd.DataFrame(rows)

# %% [markdown]
# ### Finally, the results are exported to Initial_Results.csv

# %%
df
df.to_csv(r"C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_Tests/Initial_Results.csv")
