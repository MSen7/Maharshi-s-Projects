# %%
import rdflib
import pyshacl

# %% [markdown]
# ### Import the given RDF file to process it into a more readable format. The SPARQL query extracts all the triples from the graph.

# %%
def import_rdf_graph():
    g = rdflib.Graph()
    g.parse(r"C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_Tests/statements.ttl", format="turtle")
    query = """SELECT DISTINCT ?url WHERE
    {
    {?s ?p ?o.
        BIND (?s AS ?url) }
         UNION
        { ?s ?p ?o. BIND (?p as ?url) }
        UNION
        { ?s ?p ?o. BIND (?o as ?url) }
    }   
    """
    results = g.query(query)
    return results

# %% [markdown]
# ### Define a function get_delimiter to get the last '/' or '#'. For example: passing the URL https://fuelcellsworks.com/subscribers/first-injection-of-green-hydrogen-into-the-existing-northern-german-gas-pipeline-network/New_York to this function will return '/' as it is the last '/' or '#' before the last part of the URL, 'New_York'.

# %%
def get_delimiter(url):
    if '#' in url:
        delimiter = '#'
    else:
        delimiter = '/'
    return delimiter

# %% [markdown]
# ### Process the namespaces further to remove extra  commas and opening brackets from the namespaces using the function further_processing_for_namespaces

# %%
def further_processing_for_namespaces(results):
    further_processed_list = []
    for result in results:
        temp_str = str(result).split('(')[1]
        if temp_str == 'rdflib.term.URIRef':
            uri = rdflib.term.URIRef(result)
            uri_str = str(uri)
            delimiter = get_delimiter(uri_str)
            shortened_uri_str = (('/'.join(uri_str.split(delimiter)[:-1]) + delimiter).split("(")[2]).split("'")[1]
            further_processed_list.append(shortened_uri_str)

    further_processed_list = set(further_processed_list)    
    return further_processed_list

# %% [markdown]
# ### I will now generate prefixes of length 3 for each of the namespaces using the random module. The prefixes, along with the namespaces, will be exported to the prefixes.txt text file.

# %%
def namespaces(processed_results):
    import random
    import string
    prefix_list = []

    df=open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/prefixes.txt','w+')
    for result in processed_results:
        prefixes = ''.join(random.choices(string.ascii_lowercase, k=3))
        prefix_list.append(prefixes)
    for prefix, result in zip(prefix_list,processed_results):
         line = "@prefix {}: <{}> .".format(prefix, result)
         df.write(line)
         df.write('\n') 
    df.close()

# %% [markdown]
# ### Now, the triples are exported to a fresh file output.txt.We then re-read the contents of output.txt, and replace the last '>' in every subject, predicate and object URL with a blank space. This is necessary for putting all subjects, predicates and objects in 'prefix:abc' format. Without this, after replacing the namespaces for prefixes, we would be left with something like 'prefix:abc>'.We then write our modified triplets to output1.txt

# %%
def put_whitespaces():
    from rdflib import Graph
    # Load the Turtle file into an RDF graph
    g = Graph()
    g.parse(r"C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_Tests/statements.ttl", format="turtle")

    # Open a text file for writing
    with open("C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/output.txt", "w") as f:
    # Iterate over the triples in the graph and write them to the file
        for subject, predicate, object in g:
            f.write(f"<{subject}> <{predicate}> <{object}>.\n")
            f.write('\n') 
    f.close()
    # Open the file
    file = open("C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output.txt", "r")

    # Read the contents of the file
    contents = file.read()

    # Close the file
    file.close()

    # Replace the character(s)
    new_contents = contents.replace(">", "")

    # Open the file in write mode
    file = open("C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output1.txt", "w")

    # Write the modified contents to the file
    file.write(new_contents)

    # Close the file
    file.close()

# %% [markdown]
# ### It is important to note at this point, that this part involves a little bit of manual work. The text from prefix.txt was copied to an csv file Prefix_processing.csv. It was then delimited based on the characters '@'and '>' in order to enable matching of the prefixes with the namespaces in output1.txt.

# %%
def read_file():
    import pandas as pd
    test_df = pd.read_csv(r"C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/Prefix_Processing.csv", encoding = 'unicode_escape', delimiter=';')
    
    '''This code is essential to ensure that correct prefixes are assigned to the correct namespaces, for example: if two namespaces start with similar text, then, without sorting, 
    the namespaces may get matched to the prefix corresponding to the shorter namespace, since it appears first in the list, which is not correct. 
    This step ensures that doesn't happen.'''
    
    res = test_df.SITE.str.len().sort_values(ascending = False).index 

    # Display Modified DataFrame
    new_test_df = test_df.reindex(res)
    new_test_df = new_test_df.reset_index(drop = True)
    new_test_df.rename(columns ={'ï»¿PREFIX':'PREFIX'},inplace = True)
    return new_test_df

# %% [markdown]
# ### Finally, we replace all the namespaces in output1.txt with their correct prefixes.

# %%
def replace_namespaces_with_prefixes(new_test_df):
    with open("C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output1.txt", 'r') as file:
        # read the contents of the file
        text = file.read()

        # replace "old" with "new"
    for index, row in new_test_df.iterrows():
        text = text.replace(row['SITE'], row['PREFIX'])

    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output2.txt', 'w') as file:
        # write the modified text to the file
        file.write(text)
        file.close()

# %% [markdown]
# ### It is now discovered at this point, that several triples have special characters in them; ex: abc:New-York, which cannot be correctly parsed by rdflib or pyshacl.
# ### It is necessary at this point, that we replace all special characters with '_'.

# %%
def replace_special_chars():
    import re

    # Open the file and read its contents
    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output2.txt', 'r') as file:
        data = file.read()

    # Use regex to find all special characters in the file
    special_chars = re.findall('[^a-zA-Z0-9\n\s]', data)

    # Print the list of special characters
    sp_char = set(special_chars)
    
    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output2.txt', 'r') as input_file:
    # Read the contents of the file
        text = input_file.read()

    # Replace all hyphens with underscores
    text = re.sub(r'-', '_', text)

    # Open the output file for writing
    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output3.txt', 'w') as output_file:
        # Write the modified text to the output file
        output_file.write(text)

    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output3.txt', 'r') as file:
        lines = file.readlines()

    for i in range(len(lines)):
        #if lines[i][-1] == '.':
            # If the second-to-last character is already a period, skip this line
            #continue
        #else:
            # Replace all periods except the last one in the line
        lines[i] = lines[i][:-1].replace('.', '_') + lines[-1]

    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output4.txt', 'w') as file:
        file.writelines(lines)
    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output4.txt', 'r') as file:
        lines = file.readlines()
    for i,line in enumerate(lines):
        line = line.strip()
        last_comma_index = line.rfind("_")
        if last_comma_index != -1:
            line = line.rsplit("_", 1)[0] + "."
            print(line)  # Output: "Hello, world;"
            lines[i] = line + '\n'  # Update the list of lines with the modified line
        else:
            print(line)
    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output4.txt', 'w') as file:
        file.writelines(lines)
    # Open the file and read its contents
    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output4.txt', 'r') as file:
        data = file.read()

    # Use regex to find all special characters in the file
    special_chars = re.findall('[^a-zA-Z0-9\n\s]', data)

    # Print the list of special characters
    sp_char = set(special_chars)
    special_char = ['%', '=', '?']
    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/output4.txt', 'r') as file:
        data = file.readlines()
    for char in special_char:
        for i, line in enumerate(data):  # Use enumerate to access the index of each line
            if char in line:
                   data[i] = line.replace(char, '_')  # Update the line in the list
    #for line in data:
        #print(line)  # Print the modified lines'
    with open('C:/Users/mahar/OneDrive/Desktop/Fraunhofer/Hydrogen/First_tests/final_output.txt', 'w') as file:
        file.writelines(data)

# %%
first_variable = further_processing_for_namespaces(import_rdf_graph())
second_variable = namespaces(first_variable)
put_whitespaces()
third_variable = replace_namespaces_with_prefixes(read_file())
replace_special_chars()
# Out:
# tfw:highly_compressed_hydrogen sfi:type ttl:inProduction.
#
# tfw:the_Suiso_Frontier sfi:type ttl:inProduction.
#
# tfw:Storengy sfi:type ttl:Manufacturer.
#
# tfw:Embracing_Hydrogen_and_Fuel_Cell_Technologies_Energy_Department sfi:type ttl:inProduction.
#
# tfw:production sfi:type ttl:inResearch.
#
# tfw:solar sfi:type ttl:inResearch.
#
# tfw:LONDON sfi:type ttl:Customer.
#
# tfw:a_fuel_cell_electric sfi:type ttl:inResearch.
#
# tfw:Volvo_Group sfi:type ttl:Supplier.
#
# tfw:Climate_Action_Champions sfi:type ttl:inProduction.
#
# tfw:NJC sfi:type ttl:Supplier.
#
# vcb:Initiative_seeks_to_reduce_green_hydrogen_cost_htm sfi:type bbq:BibliographicResource.
#
# tfw:Toyota_Motor_Corporation sfi:type ttl:Supplier.
#
# tfw:Hydrogen_NEXO_Vehicle_POSCO sfi:type czz:Road.
#
# tfw:University sfi:type ttl:Supplier.
#
# tfw:Hydrogen sfi:type ttl:inTesting.
#
# tfw:UK sfi:type ttl:Customer.
#
# tfw:technology sfi:type czz:Product.
#
# tfw:Amazon sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_fuel_and sfi:type ttl:inResearch.
#
# tfw:hydrogen_fuel_cell sfi:type czz:Reconversion.
#
# tfw:Ref__XX sfi:type ttl:inProduction.
#
# tfw:Volvo_AB sfi:type ttl:Manufacturer.
#
# tfw:Oakley_Men sfi:type ttl:Manufacturer.
#
# tfw:CD_Projekt_Red sfi:type ttl:Researcher.
#
# tfw:CrystEngComm sfi:type ttl:Researcher.
#
# tfw:hydrogen sfi:type ttl:Customer.
#
# tfw:hydrogen_fuel sfi:type ttl:inResearch.
#
# tfw:hydrogen_fuel_%2C sfi:type ttl:inProduction.
#
# tfw:hydrogen_train sfi:type ttl:inTesting.
#
# tfw:Green_hydrogen sfi:type ttl:Manufacturer.
#
# tfw:mouth_wash sfi:type ttl:inProduction.
#
# mfz:dni_metals_inc_appoints_lithium_ion_battery_and_fuel_cell_experts_board_directors sfi:type bbq:BibliographicResource.
#
# tfw:Bloom sfi:type ttl:Manufacturer.
#
# tfw:HTWO sfi:type ttl:Researcher.
#
# tfw:GazelEnergie_Join_Forces sfi:type ttl:inProduction.
#
# tfw:Renewable_hydrogen sfi:type ttl:Researcher.
#
# tfw:zero_emission_technology sfi:type czz:Product.
#
# zzf: sfi:type bbq:BibliographicResource.
#
# tfw:Fortescue_Metals_Group sfi:type ttl:Supplier.
#
# tfw:Sunglasses sfi:type ttl:inResearch.
#
# tfw:a_product_that_gamers_can_enjoy_as_intended sfi:type czz:Product.
#
# tfw:hydrogen_fuel sfi:type ttl:Researcher.
#
# tfw:ZeroAvia sfi:type ttl:Customer.
#
# tfw:Royal_Society_of_Chemistry sfi:type ttl:Researcher.
#
# tfw:Toyota sfi:type ttl:Customer.
#
# tfw:green_hydrogen sfi:type ttl:inResearch.
#
# tfw:Hydrogen sfi:type ttl:Supplier.
#
# tfw:hydrogen_trains sfi:type ttl:inProduction.
#
# tfw:ORR sfi:type ttl:Customer.
#
# tfw:Hydrogen_%26_Fuel_Cells sfi:type ttl:Supplier.
#
# tfw:Twitter sfi:type ttl:Researcher.
#
# tfw:Mn_Ru sfi:type ttl:inProduction.
#
# tfw:Energy_Department sfi:type ttl:Researcher.
#
# tfw:green_hydrogen sfi:type ttl:Researcher.
#
# tfw:Hydrogen_fuel_cells sfi:type ttl:Customer.
#
# efc:Oakley_Men_s_Sunglasses_Valve_Polarized_111_Fuel_Cell_Polarized_90_amp_More_Free_Shipping_8788987 sfi:type bbq:BibliographicResource.
#
# tfw:SOFC4Maritime sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_production sfi:type ttl:Customer.
#
# tfw:Australia sfi:type ttl:Customer.
#
# tfw:ALICE sfi:type ttl:Manufacturer.
#
# tfw:Lithium_Ion_Battery sfi:type ttl:inProduction.
#
# tfw:English sfi:type ttl:Supplier.
#
# tfw:Near_Future_Propulsion_Extras sfi:type ttl:inResearch.
#
# tfw:CEC sfi:type ttl:Manufacturer.
#
# tfw:Fuel_Cell_Polarized sfi:type czz:Reconversion.
#
# tfw:Matthias_Jurytko sfi:type ttl:Supplier.
#
# tfw:hydrogen_technology sfi:type ttl:Customer.
#
# tfw:road_transport sfi:type czz:Mobile.
#
# tfw:LONDON sfi:type ttl:inResearch.
#
# tfw:Activision sfi:type ttl:Supplier.
#
# tfw:Daimler_Truck_AG sfi:type ttl:Customer.
#
# tfw:Stellantis sfi:type ttl:Manufacturer.
#
# tfw:renewable_energy sfi:type ttl:inTesting.
#
# tfw:High_Pressure_Hydrogen_Tanks sfi:type ttl:Manufacturer.
#
# tfw:to_replace_heavy_duty_trucks_powered_by_diesel_fuel sfi:type czz:Truck.
#
# tfw:Kawasaki_Heavy_Industries sfi:type ttl:Customer.
#
# tfw:multi_use_passenger_vehicles sfi:type czz:Road.
#
# tfw:electric_vehicles sfi:type ttl:Supplier.
#
# tfw:Alfa_Laval sfi:type ttl:Supplier.
#
# bzd: sfi:type bbq:BibliographicResource.
#
# tfw:LONDON sfi:type ttl:Researcher.
#
# tfw:2020 sfi:type ttl:inProduction.
#
# tfw:Include_Hydrogen sfi:type ttl:inProduction.
#
# tfw:a_nano_metal_catalyst sfi:type ttl:inProduction.
#
# tfw:hydrogen sfi:type ttl:inResearch.
#
# tfw:Hydrogen_and_Fuel_Cell_Technologies sfi:type ttl:inProduction.
#
# tfw:Beiqi_Foton_Motor sfi:type ttl:Customer.
#
# tfw:Video sfi:type ttl:inProduction.
#
# tfw:UK sfi:type ttl:Researcher.
#
# tfw:polymer sfi:type ttl:inProduction.
#
# tfw:hydrogen_transportation sfi:type ttl:inProduction.
#
# tfw:railway_lines sfi:type czz:Train.
#
# tfw:product sfi:type ttl:inTesting.
#
# tfw:hydrogen_production sfi:type czz:HydrogenProduct.
#
# tfw:renewable_and_low_carbon_hydrogen sfi:type ttl:inProduction.
#
# tfw:the_Suiso_Frontier sfi:type ttl:inTesting.
#
# tfw:MnCNRu sfi:type ttl:Supplier.
#
# tfw:renewable_energy sfi:type ttl:Supplier.
#
# tfw:natural_gas sfi:type ttl:Supplier.
#
# tfw:ZeroAvia sfi:type ttl:inResearch.
#
# tfw:STT sfi:type ttl:Researcher.
#
# tfw:cellcentric sfi:type ttl:Researcher.
#
# tfw:heavy_duty_vehicles sfi:type czz:Road.
#
# tfw:fuel_cells sfi:type ttl:inResearch.
#
# izl: sfi:type bbq:BibliographicResource.
#
# tfw:Toyota_Motor_Corporation sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_technology sfi:type czz:HydrogenProduct.
#
# tfw:University sfi:type ttl:Manufacturer.
#
# tfw:San_Francisco sfi:type ttl:Customer.
#
# tfw:Fuel_Cell_Polarized sfi:type czz:Product.
#
# tfw:produce sfi:type ttl:Customer.
#
# tfw:ZeroAvia sfi:type ttl:Researcher.
#
# tfw:water_when_it_burns sfi:type ttl:inProduction.
#
# tfw:Ref__XX sfi:type ttl:inTesting.
#
# tfw:HyET_Hydrogen sfi:type ttl:Customer.
#
# tfw:Zhao sfi:type ttl:Supplier.
#
# tfw:Hyundai sfi:type ttl:Researcher.
#
# tfw:Hydrogen_fuel_cells sfi:type ttl:inResearch.
#
# tfw:hydrogen_fuel_%2C sfi:type ttl:inTesting.
#
# tfw:fuel_cell_electric_vehicles sfi:type ttl:inProduction.
#
# tfw:Korea_Institute_of_Science_and_Technology sfi:type ttl:Researcher.
#
# tfw:Development_of_a_Hydrogen_Infrastructure sfi:type czz:Road.
#
# tfw:Mads_Friis_Jensen sfi:type ttl:Customer.
#
# tfw:liquefied_hydrogen_carrier sfi:type czz:Car.
#
# tfw:hydrogen_production sfi:type ttl:inResearch.
#
# tfw:Australia sfi:type ttl:inResearch.
#
# tfw:applications sfi:type ttl:Researcher.
#
# tfw:solar sfi:type ttl:inTesting.
#
# tfw:Toyota sfi:type ttl:inProduction.
#
# tfw:Fuel_Cell sfi:type ttl:Customer.
#
# tfw:Fuel_Cells sfi:type czz:Reconversion.
#
# kds:3217 sfi:type bbq:BibliographicResource.
#
# tfw:Vanguard sfi:type ttl:Manufacturer.
#
# tfw:Oakley_Men%27s_Sunglasses sfi:type ttl:Supplier.
#
# tfw:Hydrogen_Peroxide sfi:type ttl:inProduction.
#
# tfw:hydrogen_technology sfi:type ttl:inResearch.
#
# tfw:Australia sfi:type ttl:Researcher.
#
# tfw:Hydrogen sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_in sfi:type ttl:Customer.
#
# tfw:Orange_County_Transportation_Authority sfi:type ttl:inProduction.
#
# tfw:Plug_Power_Fuel_Cells sfi:type czz:Reconversion.
#
# tfw:Hydrogen_Fuel_Cell_Buses sfi:type czz:Bus.
#
# tfw:Toyoda_Gosei sfi:type ttl:Supplier.
#
# tfw:hydrogen_fuel_%2C sfi:type ttl:Supplier.
#
# tfw:zero_carbon_hydrogen sfi:type czz:Car.
#
# tfw:solid_oxide_fuel_cells sfi:type ttl:Customer.
#
# zpz:toyoda_gosei_starts_operation_high_pressure_hydrogen_tanks_fcvs_inabe_plant_japan sfi:type bbq:BibliographicResource.
#
# tfw:hydrogen_technology sfi:type ttl:Researcher.
#
# tfw:hydrogen_and_fuel_cell_technologies sfi:type ttl:inProduction.
#
# tfw:GLOBE_NEWSWIRE sfi:type ttl:Supplier.
#
# tfw:a_fuel_cell_electric sfi:type ttl:Supplier.
#
# tfw:CD_Projekt_Red sfi:type ttl:Supplier.
#
# tfw:CrystEngComm sfi:type ttl:Supplier.
#
# tfw:Kawasaki_Heavy_Industries sfi:type ttl:Researcher.
#
# tfw:Toyoda_Gosei_Co__%2C_Ltd sfi:type ttl:Researcher.
#
# tfw:Channel_10 sfi:type ttl:Supplier.
#
# tfw:Hydrogen_Fuel_Cell sfi:type ttl:inProduction.
#
# tfw:governments_and_businesses sfi:type ttl:Supplier.
#
# tfw:SOFC4Maritime sfi:type czz:Marine.
#
# tfw:Toyota_Motor_Europe sfi:type czz:Manufacturing.
#
# tfw:carbon_free_hydrogen sfi:type czz:Car.
#
# tfw:mining sfi:type ttl:Researcher.
#
# qxf: sfi:type bbq:BibliographicResource.
#
# tfw:Reuters sfi:type ttl:inProduction.
#
# tfw:Volvo sfi:type ttl:Customer.
#
# tfw:Beijing sfi:type ttl:Manufacturer.
#
# tfw:aircraft sfi:type ttl:Researcher.
#
# tfw:Activision sfi:type ttl:Manufacturer.
#
# tfw:technology sfi:type ttl:Customer.
#
# tfw:Perovskites_crystals sfi:type ttl:inProduction.
#
# tfw:Dezember_2020 sfi:type ttl:inResearch.
#
# tfw:Storengy sfi:type ttl:Researcher.
#
# tfw:Fuel_Cells sfi:type czz:Product.
#
# tfw:produce sfi:type ttl:inResearch.
#
# tfw:renewable_energy_sources sfi:type ttl:Supplier.
#
# tfw:Geely_Hydrogen_Fuel_Cell sfi:type czz:Reconversion.
#
# tfw:products sfi:type ttl:inResearch.
#
# tfw:News_Engineered_Products sfi:type ttl:Researcher.
#
# tfw:Thiebault_Paquet sfi:type ttl:Supplier.
#
# tfw:Hyundai_Motor_Group sfi:type ttl:Customer.
#
# tfw:ECH2A sfi:type ttl:Supplier.
#
# tfw:Hydrogen_and_Fuel_Cell_Technologies sfi:type ttl:inTesting.
#
# tfw:Inabe_Plant sfi:type ttl:inProduction.
#
# tfw:Plug_Power_Fuel_Cells sfi:type czz:Product.
#
# tfw:applications sfi:type czz:Application.
#
# tfw:Video sfi:type ttl:inTesting.
#
# tfw:natural_gas_distribution_system sfi:type czz:Bus.
#
# tfw:OCTA sfi:type ttl:Supplier.
#
# tfw:next_generation sfi:type ttl:inProduction.
#
# tfw:renewable_and_low_carbon_hydrogen sfi:type ttl:inTesting.
#
# tfw:The_European_Union sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_fuel_cells sfi:type ttl:inProduction.
#
# tfw:MnCNRu sfi:type ttl:Manufacturer.
#
# tfw:renewable_energy sfi:type ttl:Manufacturer.
#
# tfw:Nafion sfi:type ttl:Customer.
#
# tfw:Bloom sfi:type ttl:Researcher.
#
# tfw:Maanshan_City sfi:type ttl:Customer.
#
# tfw:proton_exchange_membranes sfi:type ttl:inProduction.
#
# tfw:methanol_fuel_cell sfi:type czz:MethanolFuelCell.
#
# tfw:hydrogen_fuel_cell_system sfi:type czz:Reconversion.
#
# tfw:China sfi:type ttl:Customer.
#
# tfw:Stockholm_University sfi:type czz:Research.
#
# tfw:Archive_org sfi:type ttl:Researcher.
#
# tfw:carbon_free_hydrogen sfi:type ttl:inResearch.
#
# tfw:Antiseptic_Mouth_Wash sfi:type ttl:Manufacturer.
#
# yfw: sfi:type bbq:BibliographicResource.
#
# tfw:contribute_to_the_development_of_zero_carbon_hydrogen sfi:type czz:Road.
#
# tfw:Strategic_Analysis%2C_Inc sfi:type ttl:Researcher.
#
# tfw:Hyundai_Motor_Group sfi:type czz:Manufacturing.
#
# tfw:Mads_Friis_Jensen sfi:type ttl:inProduction.
#
# tfw:Daimler_Truck_Fuel_Cell sfi:type ttl:Customer.
#
# tfw:H2O2 sfi:type ttl:inProduction.
#
# tfw:solid_oxide_fuel_cells sfi:type ttl:inResearch.
#
# tfw:Blue_World_Technologies sfi:type ttl:inResearch.
#
# tfw:zero_emission_electric_cars sfi:type czz:Car.
#
# tfw:fuel_cell sfi:type ttl:inResearch.
#
# tfw:Toyota_Motor_Europe sfi:type ttl:Researcher.
#
# tfw:vehicles sfi:type ttl:Customer.
#
# tfw:Fuel_Cell sfi:type ttl:inProduction.
#
# tfw:hydrogen_in sfi:type ttl:Researcher.
#
# tfw:LONDON sfi:type ttl:Supplier.
#
# tfw:Hydrogen_Cars sfi:type czz:Car.
#
# tfw:The_Clean_Hydrogen_Alliance sfi:type ttl:Researcher.
#
# tfw:Daimler_Truck_Fuel_Cell_GmbH_%26_Co_KG sfi:type czz:Reconversion.
#
# tfw:Heavy_Duty_Vehicles_Hydrogen sfi:type czz:Truck.
#
# tfw:Wind_Hunter_Project sfi:type ttl:Customer.
#
# tfw:Geely_Hydrogen_Fuel_Cell sfi:type czz:Product.
#
# tfw:solid_oxide_fuel_cells sfi:type ttl:Researcher.
#
# tfw:Advance_Article sfi:type ttl:Supplier.
#
# tfw:Blue_World_Technologies sfi:type ttl:Researcher.
#
# tfw:UK sfi:type ttl:Supplier.
#
# tfw:hydrogen_bond_donor_scaffolds sfi:type ttl:inProduction.
#
# tfw:Talgo_Vittal_One sfi:type ttl:Customer.
#
# tfw:a_new_technology sfi:type ttl:inProduction.
#
# tfw:Hydrogen_Peroxide sfi:type ttl:inTesting.
#
# tfw:hydrogen sfi:type ttl:Supplier.
#
# tfw:Daimler_Truck_AG sfi:type czz:Truck.
#
# tfw:Ammonia_Fuel_Cells sfi:type czz:Reconversion.
#
# tfw:Phenanthrene_Skeletons sfi:type ttl:inProduction.
#
# tfw:Toyoda_Gosei sfi:type ttl:Manufacturer.
#
# tfw:technology sfi:type ttl:inResearch.
#
# tfw:Daimler_AG sfi:type ttl:Customer.
#
# tfw:application sfi:type ttl:Supplier.
#
# tfw:Talgo sfi:type ttl:Customer.
#
# tfw:hydrogen_production sfi:type ttl:inTesting.
#
# bzh:index_php?nr=393867 sfi:type bbq:BibliographicResource.
#
# tfw:hydrogen_and_fuel_cell_technologies sfi:type ttl:inTesting.
#
# tfw:hydrogen_fuel_cell_system sfi:type czz:Product.
#
# tfw:ZeroAvia sfi:type ttl:Supplier.
#
# tfw:hydrogen_projects sfi:type zpq:Project.
#
# tfw:High_Pressure_Hydrogen_Tanks sfi:type ttl:Researcher.
#
# tfw:Toyota sfi:type ttl:Supplier.
#
# tfw:methanol_fuel_cell sfi:type czz:Reconversion.
#
# tfw:electric_vans sfi:type czz:RegionalTruck.
#
# tfw:the_production sfi:type ttl:Manufacturer.
#
# tfw:zero_emission_technology sfi:type ttl:inResearch.
#
# tfw:Hydrogen_Fuel_Cell sfi:type ttl:inTesting.
#
# tfw:ORR sfi:type ttl:Supplier.
#
# tfw:a_six_seater_propeller_plane_powered_by_hydrogen sfi:type czz:Aircraft.
#
# tfw:a_product_that_gamers_can_enjoy_as_intended sfi:type ttl:inResearch.
#
# tfw:hydrogen_trains sfi:type ttl:Manufacturer.
#
# tfw:electric_vehicles sfi:type czz:Road.
#
# tfw:Tuesday sfi:type ttl:inProduction.
#
# tfw:Hyundai_Motor_Group sfi:type ttl:Researcher.
#
# tfw:Orange_County_Transportation_Authority sfi:type czz:Mobile.
#
# tfw:H2O_Molecules sfi:type ttl:inResearch.
#
# tfw:Santa_Cruz sfi:type ttl:Researcher.
#
# tfw:catalyst sfi:type ttl:inResearch.
#
# tfw:Daimler_Truck_Fuel_Cell_GmbH_%26_Co_KG sfi:type czz:Product.
#
# tfw:Lithium_Ion_Battery_and_Fuel_Cell sfi:type czz:Reconversion.
#
# tfw:hydrogen_production sfi:type ttl:Supplier.
#
# tfw:Australia sfi:type ttl:Supplier.
#
# tfw:Ammonia sfi:type ttl:inResearch.
#
# tfw:Perovskites_crystals sfi:type ttl:inTesting.
#
# tfw:fuel_cell_system sfi:type ttl:inProduction.
#
# tfw:Southern_California sfi:type ttl:Customer.
#
# tfw:fuel_cell_vehicles sfi:type ttl:inTesting.
#
# tfw:China sfi:type ttl:Researcher.
#
# tfw:hydrogen_transportation sfi:type czz:Transport.
#
# tfw:ECH2A sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_technology sfi:type ttl:Supplier.
#
# tfw:Ammonia_Fuel_Cells sfi:type czz:Product.
#
# tfw:Daimler_Truck_AG sfi:type ttl:Supplier.
#
# tfw:hydrogen_fuel_cell sfi:type ttl:inResearch.
#
# tfw:Spyro_Reignited sfi:type ttl:inProduction.
#
# tfw:mobility sfi:type ttl:inResearch.
#
# tfw:Lhyfe sfi:type ttl:Manufacturer.
#
# tfw:next_generation sfi:type ttl:inTesting.
#
# tfw:Kawasaki_Heavy_Industries sfi:type ttl:Supplier.
#
# tfw:hydrogen_fuel_cells sfi:type ttl:inTesting.
#
# xcr:product_owner_d_engineering_it_daimler_truck_fuel_cell_gmbh_co_kg_stellenangebot_1346832_html sfi:type bbq:BibliographicResource.
#
# tfw:HTWO sfi:type ttl:Customer.
#
# tfw:Fuel_Cell_Business sfi:type czz:Product.
#
# tfw:methanol_fuel_cell sfi:type czz:Product.
#
# tfw:fuel_cells_are sfi:type ttl:inProduction.
#
# tfw:hydrogen_fuel_cell sfi:type ttl:Researcher.
#
# tfw:Brooklyn_College_of_the_City_University_of_New_York sfi:type czz:Research.
#
# tfw:Wind_Hunter_Project sfi:type ttl:Researcher.
#
# tfw:Beiqi_Foton_Motor sfi:type ttl:Supplier.
#
# tfw:electric_vehicles sfi:type ttl:inProduction.
#
# tfw:solid_oxide_fuel_cells sfi:type czz:SolidOxideFuelCell.
#
# tfw:Fuel_Cell_System sfi:type czz:Reconversion.
#
# tfw:Dedicated_Fuel_Cell_System sfi:type ttl:inProduction.
#
# tfw:Mads_Friis_Jensen sfi:type ttl:inTesting.
#
# tfw:Fuel_Cell sfi:type ttl:inTesting.
#
# tfw:Lithium_Ion_Battery_and_Fuel_Cell sfi:type czz:Product.
#
# tfw:News_Engineered_Products sfi:type ttl:Supplier.
#
# tfw:The_Korea_Institute_of_Science_and_Technology sfi:type jgy:RegisteredOrganization.
#
# tfw:DOI sfi:type ttl:Customer.
#
# tfw:Energy_Department sfi:type ttl:Customer.
#
# tfw:green_hydrogen sfi:type ttl:Customer.
#
# tfw:Hydrogen_Infrastructure sfi:type ttl:Manufacturer.
#
# tfw:Daimler_AG sfi:type ttl:Researcher.
#
# tfw:Talgo sfi:type ttl:Researcher.
#
# tfw:natural_gas sfi:type ttl:inProduction.
#
# tfw:zero_emission_train sfi:type czz:Train.
#
# tfw:Green_hydrogen sfi:type czz:Conversion.
#
# tfw:fossil_fuel sfi:type ttl:inResearch.
#
# tfw:fuel_cell_joint_venture sfi:type zpq:Project.
#
# tfw:Fuel_Cell_Polarized sfi:type ttl:inResearch.
#
# tfw:hydrogen_cars sfi:type czz:Car.
#
# tfw:Fuel_cell_power_pack sfi:type ttl:Supplier.
#
# tfw:Fuel_Cell_Technologies sfi:type czz:Reconversion.
#
# tfw:Cellcentric sfi:type ttl:inResearch.
#
# tfw:clean_energy sfi:type ttl:inProduction.
#
# tfw:Toyota sfi:type ttl:Manufacturer.
#
# tfw:high_pressure_hydrogen_tanks sfi:type ttl:inResearch.
#
# tfw:hydrogen_in sfi:type ttl:Supplier.
#
# tfw:Fuel_Cell_System sfi:type czz:Product.
#
# tfw:ORR sfi:type ttl:Manufacturer.
#
# tfw:Doritos sfi:type ttl:inTesting.
#
# tfw:Tuesday sfi:type ttl:inTesting.
#
# tfw:solid_oxide_fuel_cells sfi:type ttl:Supplier.
#
# tfw:technology sfi:type ttl:inTesting.
#
# tfw:new_hydrogen_vehicle sfi:type ttl:inResearch.
#
# dlc:_Friday sfi:type ttl:Customer.
#
# vni:_media_organizations sfi:type ttl:Supplier.
#
# tfw:Renewable_hydrogen sfi:type ttl:inResearch.
#
# tfw:hydrogen_fuel_and_wind_power sfi:type ttl:inResearch.
#
# tfw:Breakthrough_Energy_Ventures sfi:type zpq:Project.
#
# tfw:fuel_cell_system sfi:type ttl:inTesting.
#
# tfw:STT sfi:type ttl:Customer.
#
# tfw:SoCalGas sfi:type ttl:Manufacturer.
#
# tfw:production sfi:type ttl:inProduction.
#
# tfw:GLOBE_NEWSWIRE sfi:type ttl:inProduction.
#
# tfw:Methanol_fuel_cell_system sfi:type czz:EthanolFuelCell.
#
# tfw:a_fuel_cell_electric sfi:type ttl:inProduction.
#
# tfw:solar sfi:type ttl:inProduction.
#
# tfw:Volvo sfi:type ttl:Supplier.
#
# tfw:a_product_that_gamers_can_enjoy_as_intended sfi:type ttl:inTesting.
#
# tfw:1st_Hydrogen_NEXO_Vehicle sfi:type czz:Road.
#
# tfw:Featured_Company_Featured_Company_DNI_Metals_Inc sfi:type ttl:Researcher.
#
# tfw:HTWO sfi:type ttl:inProduction.
#
# tfw:H2 sfi:type ttl:inResearch.
#
# tfw:Hyundai sfi:type ttl:Customer.
#
# tfw:Reuters sfi:type ttl:Manufacturer.
#
# tfw:Stockholm_University sfi:type ttl:Researcher.
#
# tfw:Fuel_Cell_Technologies sfi:type czz:Product.
#
# tfw:hydrogen_and_fuel sfi:type ttl:inResearch.
#
# tfw:hydrogen_fuel_and sfi:type ttl:inProduction.
#
# tfw:technology sfi:type ttl:Supplier.
#
# <https://fuelcellsworks_com/subscribers/swk_opts_for_green_hydrogen_production_in_cooperation_with_the_swk_e²_institute_of_the_niederrhein_university_of_applied_sciences/ sfi:type bbq:BibliographicResource.
#
# tfw:FuelCellsWorks sfi:type ttl:Customer.
#
# tfw:Methanol_fuel_cell_system sfi:type czz:MethanolFuelCell.
#
# tfw:hydrogen_fuel sfi:type ttl:inProduction.
#
# tfw:fuel_cells_are sfi:type ttl:inTesting.
#
# tfw:hydrogen_cars sfi:type ttl:Researcher.
#
# tfw:DOI sfi:type ttl:Researcher.
#
# tfw:Hyundai_Motor_Group sfi:type ttl:Supplier.
#
# tfw:zero_emissions_transportation sfi:type czz:Mobile.
#
# tfw:H2 sfi:type ttl:Researcher.
#
# tfw:the_Alfa_Laval_Test_and_Training_Centre sfi:type czz:Train.
#
# tfw:ACWA_Power sfi:type ttl:Customer.
#
# tfw:methanol sfi:type ttl:inResearch.
#
# tfw:Beiqi_Foton_Motor sfi:type ttl:Manufacturer.
#
# tfw:Sunglasses sfi:type ttl:inProduction.
#
# tfw:Fuel_Cells sfi:type ttl:inResearch.
#
# tfw:proton_conducting_fuel_cells sfi:type czz:Reconversion.
#
# tfw:Fukushima_Prefecture sfi:type ttl:Researcher.
#
# tfw:hydrogen_fuel_cell_system sfi:type ttl:Customer.
#
# tfw:Dedicated_Fuel_Cell_System sfi:type ttl:inTesting.
#
# tfw:Inabe_Plant sfi:type ttl:Manufacturer.
#
# tfw:green_hydrogen sfi:type ttl:inProduction.
#
# tfw:proton_exchange_membranes sfi:type czz:Membrane.
#
# tfw:hydrogen_fuel_cell sfi:type czz:Product.
#
# tfw:Nafion sfi:type ttl:Supplier.
#
# tfw:Maanshan_City sfi:type ttl:Supplier.
#
# tfw:hydrogen_and_fuel sfi:type ttl:inProduction.
#
# tfw:mobility sfi:type ttl:inTesting.
#
# tfw:STOL sfi:type czz:Aircraft.
#
# tfw:AUVSI sfi:type ttl:Manufacturer.
#
# tfw:fuel_and sfi:type ttl:inResearch.
#
# tfw:Fuel_Cells sfi:type ttl:Researcher.
#
# tfw:China sfi:type ttl:Supplier.
#
# tfw:natural_gas sfi:type ttl:inTesting.
#
# tfw:San_Francisco sfi:type ttl:Manufacturer.
#
# tfw:the_%E2%80%9C_European_Clean_Hydrogen_Alliance sfi:type ttl:inResearch.
#
# tfw:aircraft sfi:type czz:Aircraft.
#
# tfw:fuel_cell_electric_vehicles sfi:type czz:Road.
#
# tfw:Daimler_Truck_Fuel_Cell sfi:type ttl:Supplier.
#
# tfw:HyET_Hydrogen sfi:type ttl:Manufacturer.
#
# tfw:Toyoda_Gosei_Co__%2C_Ltd sfi:type ttl:Customer.
#
# tfw:vehicles sfi:type ttl:Supplier.
#
# tfw:zero_emission_hydrogen_fuel_cell_bus sfi:type czz:Bus.
#
# tfw:mining sfi:type ttl:Customer.
#
# tfw:Hydrogen_fuel_cars sfi:type czz:Car.
#
# tfw:vehicles_and_portable_devices sfi:type czz:Road.
#
# tfw:H2O2 sfi:type ttl:Manufacturer.
#
# tfw:aircraft sfi:type ttl:Customer.
#
# tfw:freight_hauling_trucks sfi:type czz:Truck.
#
# tfw:Fuel_Cell sfi:type ttl:Manufacturer.
#
# dlc:_Friday sfi:type ttl:Researcher.
#
# tfw:Methanol_fuel_cell_system sfi:type czz:Reconversion.
#
# tfw:LONDON sfi:type ttl:inProduction.
#
# tfw:Talgo_Vittal_One sfi:type ttl:Supplier.
#
# tfw:Storengy sfi:type ttl:Customer.
#
# tfw:University sfi:type czz:Research.
#
# tfw:Advance_Article sfi:type ttl:inProduction.
#
# tfw:proton_conducting_fuel_cells sfi:type czz:Product.
#
# tfw:Hyundai sfi:type ttl:inResearch.
#
# tfw:Ammonia_Fuel_Cells sfi:type czz:AmmoniaFuelCell.
#
# tfw:Heavy_Duty_Vehicles_Hydrogen sfi:type czz:Road.
#
# tfw:Daimler_AG sfi:type ttl:Supplier.
#
# tfw:Talgo sfi:type ttl:Supplier.
#
# tfw:FuelCellsWorks sfi:type ttl:inResearch.
#
# tfw:hydrogen sfi:type ttl:inProduction.
#
# tfw:Volvo_AB sfi:type ttl:Customer.
#
# tfw:multi_use_passenger_vehicles sfi:type czz:Car.
#
# tfw:Embracing_Hydrogen_and_Fuel_Cell_Technologies_Energy_Department sfi:type czz:Reconversion.
#
# tfw:Deep_Sea_Shipping sfi:type czz:Marine.
#
# tfw:cellcentric sfi:type ttl:inProduction.
#
# tfw:planned sfi:type ttl:Researcher.
#
# tfw:GlobeNewswire_Advanced_TORONTO sfi:type ttl:Researcher.
#
# tfw:Lhyfe sfi:type ttl:Researcher.
#
# tfw:Green_hydrogen sfi:type ttl:Customer.
#
# tfw:clean_technology_revolution sfi:type czz:Road.
#
# tfw:Spanish_utility_Iberdrola sfi:type ttl:Customer.
#
# tfw:Bloom sfi:type ttl:Customer.
#
# tfw:Avions_Mauboussin sfi:type ttl:Supplier.
#
# tfw:zero_carbon_hydrogen_solutions sfi:type czz:Car.
#
# tfw:FuelCellsWorks sfi:type ttl:Researcher.
#
# tfw:ZeroAvia sfi:type ttl:inProduction.
#
# tfw:hydrogen_fuel_cell_system sfi:type ttl:inResearch.
#
# tfw:production sfi:type ttl:inTesting.
#
# tfw:Switch_to_Hydrogen_Buses sfi:type czz:Bus.
#
# tfw:fuel_cells sfi:type ttl:inProduction.
#
# tfw:cyano_bridged_coordination_polymers sfi:type ttl:inProduction.
#
# tfw:Fortescue_Metals_Group sfi:type ttl:Manufacturer.
#
# tfw:Volvo sfi:type ttl:Manufacturer.
#
# tfw:ACWA_Power sfi:type ttl:Researcher.
#
# tzp:d0ce01311k sfi:type bbq:BibliographicResource.
#
# tfw:MAHLE sfi:type ttl:Supplier.
#
# tfw:Toyota_Motor_Europe sfi:type ttl:Customer.
#
# tfw:fuel_cell_vehicles sfi:type czz:Road.
#
# tfw:hydrogen_fuel_and sfi:type ttl:inTesting.
#
# tfw:hydrogen_fuel_cell_system sfi:type ttl:Researcher.
#
# wjs: sfi:type bbq:BibliographicResource.
#
# tfw:Methanol_fuel_cell_system sfi:type czz:Product.
#
# tfw:hydrogen_fuel sfi:type ttl:inTesting.
#
# tfw:Hydrogen_fuel_cells sfi:type ttl:inProduction.
#
# tfw:fuel_cell_modules sfi:type ttl:Customer.
#
# qtd: sfi:type bbq:BibliographicResource.
#
# tfw:Hydrogen_Infrastructure sfi:type ttl:Researcher.
#
# tfw:hydrogen_production sfi:type ttl:inProduction.
#
# tfw:Blue_World_Technologies sfi:type ttl:Customer.
#
# tfw:Australia sfi:type ttl:inProduction.
#
# tfw:product sfi:type czz:Product.
#
# tfw:decarbonising_road_transport sfi:type czz:Car.
#
# tfw:discovery sfi:type ttl:Supplier.
#
# tfw:green_hydrogen sfi:type ttl:inTesting.
#
# tfw:Daimler_Truck_Fuel_Cell_GmbH_%26_Co_KG sfi:type ttl:Researcher.
#
# tfw:CEC sfi:type ttl:Customer.
#
# tfw:Embracing_Hydrogen_and_Fuel_Cell_Technologies_Energy_Department sfi:type czz:Product.
#
# tfw:HTWO sfi:type ttl:Supplier.
#
# tfw:hydrogen_and_fuel sfi:type ttl:inTesting.
#
# tfw:Renewable_hydrogen sfi:type ttl:Supplier.
#
# tfw:hydrogen_technology sfi:type ttl:inProduction.
#
# tfw:carandbike_com sfi:type czz:Bike.
#
# tfw:McPhy sfi:type ttl:Customer.
#
# tfw:oxygen_reduction_reaction sfi:type ttl:inProduction.
#
# tfw:Stellantis sfi:type ttl:Customer.
#
# tfw:TME sfi:type ttl:inResearch.
#
# eno:canadian_pacific_to_pilot_hydrogen_powered_train_to_decarbonize_freight_transport_3195995 sfi:type bbq:BibliographicResource.
#
# tfw:Fuel_Cell_Business sfi:type ttl:inResearch.
#
# tfw:methanol_fuel_cell sfi:type ttl:inResearch.
#
# tfw:Org sfi:type ttl:Supplier.
#
# tfw:fuel_cell_vehicles sfi:type ttl:inProduction.
#
# tfw:TME sfi:type ttl:Researcher.
#
# tfw:DOI sfi:type ttl:Supplier.
#
# tfw:Energy_Department sfi:type ttl:Supplier.
#
# tfw:Green_hydrogen sfi:type ttl:inResearch.
#
# tfw:green_hydrogen sfi:type ttl:Supplier.
#
# tfw:H2 sfi:type ttl:Supplier.
#
# tfw:batteries sfi:type czz:Battery.
#
# tfw:Amazon sfi:type ttl:Researcher.
#
# tfw:ammonia sfi:type ttl:inResearch.
#
# tfw:Volvo_AB sfi:type ttl:Researcher.
#
# tfw:Oakley_Men sfi:type ttl:Researcher.
#
# tfw:Talgo_Vittal_One sfi:type ttl:Manufacturer.
#
# tfw:Lithium_Ion_Battery_and_Fuel_Cell sfi:type ttl:inResearch.
#
# tfw:Mitsui_O_S_K__Lines sfi:type ttl:Researcher.
#
# tfw:Many_provinces_and_cities sfi:type ttl:Customer.
#
# tfw:gas_storage_and_the_development_of_renewable_gases sfi:type czz:Road.
#
# tfw:natural_gas sfi:type ttl:Manufacturer.
#
# tfw:Hydrogen_and_Fuel_Cell_Technologies sfi:type czz:Reconversion.
#
# tfw:Dezember_2020 sfi:type ttl:inProduction.
#
# tfw:Advance_Article sfi:type ttl:inTesting.
#
# tfw:methanol sfi:type ttl:Supplier.
#
# tfw:produce sfi:type ttl:inProduction.
#
# tfw:Fuel_Cells sfi:type ttl:Supplier.
#
# tfw:Hydrogen_plane sfi:type ttl:Manufacturer.
#
# tfw:Alliance sfi:type ttl:Researcher.
#
# tfw:Green_Hydrogen sfi:type ttl:Researcher.
#
# tfw:products sfi:type ttl:inProduction.
#
# tfw:IEEE_Spectrum sfi:type ttl:Manufacturer.
#
# tfw:hydrogen sfi:type ttl:inTesting.
#
# tfw:ammonia sfi:type ttl:inProduction.
#
# tfw:Zhao sfi:type ttl:Manufacturer.
#
# tfw:Industry_News sfi:type ttl:Researcher.
#
# tfw:Latest_Poll sfi:type ttl:inProduction.
#
# tfw:hydrogen_transportation sfi:type czz:Mobile.
#
# tfw:POSTECH_University sfi:type czz:Research.
#
# tfw:Franco_German sfi:type ttl:Customer.
#
# tci:C6TA01470D sfi:type bbq:BibliographicResource.
#
# tfw:hydrogen_fuel_cell sfi:type ttl:Customer.
#
# tfw:Strategic_Analysis%2C_Inc_ sfi:type ttl:Researcher.
#
# tfw:fuel_cells sfi:type ttl:inTesting.
#
# dlc:_Friday sfi:type ttl:Supplier.
#
# tfw:Toyota_Motor_Corporation sfi:type czz:Manufacturing.
#
# tfw:Hydrogen_Fuel_Cell_Buses sfi:type ttl:inProduction.
#
# tfw:Vanguard sfi:type ttl:Customer.
#
# tfw:SOFC4Maritime sfi:type ttl:Researcher.
#
# tfw:carbon_free_hydrogen sfi:type ttl:inProduction.
#
# tfw:Fuel_Cell_System sfi:type ttl:inResearch.
#
# tfw:fuel_cell_modules sfi:type ttl:inProduction.
#
# tfw:solid_oxide_fuel_cells sfi:type ttl:inProduction.
#
# tfw:Blue_World_Technologies sfi:type ttl:inProduction.
#
# tfw:European sfi:type ttl:inResearch.
#
# tfw:CEC sfi:type ttl:Researcher.
#
# tfw:Breakthrough_Energy_Ventures sfi:type ttl:Researcher.
#
# tfw:fuel_cell sfi:type ttl:inProduction.
#
# tfw:Hydrogen_fuel_cells sfi:type ttl:inTesting.
#
# tfw:gas_storage_and_the_development_of_renewable_gases sfi:type ttl:inProduction.
#
# tfw:Daimler_Truck_Fuel_Cell_GmbH_%26_Co_KG sfi:type czz:Truck.
#
# tfw:prototype sfi:type ttl:inProduction.
#
# tfw:Cariba_Heine sfi:type ttl:Customer.
#
# tfw:Australia sfi:type ttl:inTesting.
#
# tfw:Stellantis sfi:type ttl:Researcher.
#
# rws:index_php?nr=610526 sfi:type bbq:BibliographicResource.
#
# tfw:CrystEngComm sfi:type ttl:Manufacturer.
#
# tfw:Hyundai sfi:type ttl:Supplier.
#
# tfw:fuel_cell_business sfi:type czz:Bus.
#
# tfw:Korea_Institute_of_Science_and_Technology sfi:type ttl:Supplier.
#
# tfw:FuelCellsWorks sfi:type ttl:Supplier.
#
# tfw:Channel_10 sfi:type ttl:Manufacturer.
#
# tfw:HTWO sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_technology sfi:type ttl:inTesting.
#
# nzi: sfi:type bbq:BibliographicResource.
#
# tfw:hydrogen_and_fuel_cell_technologies sfi:type czz:Reconversion.
#
# tfw:applications sfi:type ttl:Supplier.
#
# nrg: sfi:type bbq:BibliographicResource.
#
# tfw:Beijing sfi:type ttl:Customer.
#
# tfw:vehicles sfi:type czz:Road.
#
# tfw:European_Clean_Hydrogen_Alliance sfi:type ttl:Customer.
#
# tfw:technology sfi:type ttl:inProduction.
#
# tfw:ACWA_Power sfi:type ttl:Supplier.
#
# tfw:Fuel_Cell_Technologies sfi:type ttl:inResearch.
#
# tfw:Advance_Article sfi:type czz:RegionalTruck.
#
# tfw:Hydrogen_Fuel_Cell sfi:type czz:Reconversion.
#
# tfw:hydrogen_fuel_cell_system sfi:type ttl:Supplier.
#
# tfw:Hyundai_Motor_Group sfi:type ttl:inProduction.
#
# tfw:Many_provinces_and_cities sfi:type ttl:Researcher.
#
# tfw:NJC sfi:type ttl:Researcher.
#
# tfw:zero_emission_technology sfi:type ttl:inProduction.
#
# tfw:Energy_Department sfi:type ttl:Manufacturer.
#
# tfw:Toyota_Motor_Corporation sfi:type ttl:Researcher.
#
# tfw:green_hydrogen sfi:type ttl:Manufacturer.
#
# tfw:Fuel_Cell_Vehicles sfi:type czz:Road.
#
# tfw:University sfi:type ttl:Researcher.
#
# tfw:a_product_that_gamers_can_enjoy_as_intended sfi:type ttl:inProduction.
#
# tfw:vans sfi:type czz:RegionalTruck.
#
# tfw:The_European_Union sfi:type ttl:Customer.
#
# dva:IHS_Says_Hydrogen_Cars_Are_at_Crossroad_htm sfi:type bbq:BibliographicResource.
#
# tfw:H2O_Molecules sfi:type ttl:inProduction.
#
# tfw:OCTA sfi:type ttl:Manufacturer.
#
# tfw:Nick_Carey sfi:type ttl:Supplier.
#
# tfw:catalyst sfi:type ttl:inProduction.
#
# tfw:fuel_cell_vehicles sfi:type czz:Reconversion.
#
# tfw:Toyoda_Gosei_Co__%2C_Ltd sfi:type ttl:Supplier.
#
# tfw:China sfi:type ttl:inProduction.
#
# tfw:Daimler_Truck_Fuel_Cell_GmbH_%26_Co_KG sfi:type ttl:Supplier.
#
# tfw:Ammonia sfi:type ttl:inProduction.
#
# odm:Government_to_roll_out_promotion_of_hydrogen_efficient_fleets_aspx sfi:type bbq:BibliographicResource.
#
# tfw:UAM%2C_automobiles%2C_vessels_and_trains sfi:type czz:Train.
#
# tfw:produce sfi:type ttl:inTesting.
#
# tfw:Antiseptic_Mouth_Wash sfi:type ttl:Customer.
#
# tfw:products sfi:type ttl:inTesting.
#
# tfw:Compression sfi:type ttl:inTesting.
#
# nxq:d0qo01341b sfi:type bbq:BibliographicResource.
#
# tfw:Green_hydrogen sfi:type ttl:inTesting.
#
# tfw:hydrogen_and_fuel_cell_technologies sfi:type czz:Product.
#
# tfw:hydrogen_fuel_cells sfi:type czz:Reconversion.
#
# tfw:hydrogen_train sfi:type ttl:inResearch.
#
# tfw:Vanguard sfi:type ttl:Researcher.
#
# tfw:Hydrogen_Evolution sfi:type ttl:Supplier.
#
# tfw:Hydrogen sfi:type ttl:Researcher.
#
# tfw:Storengy sfi:type ttl:Supplier.
#
# tfw:ammonia sfi:type ttl:inTesting.
#
# tfw:hydrogen_fuel_cell sfi:type ttl:inProduction.
#
# tfw:mobility sfi:type ttl:inProduction.
#
# tfw:Hydrogen_Fuel_Cell sfi:type czz:Product.
#
# tfw:Hydrogen_%26_Fuel_Cells sfi:type ttl:Researcher.
#
# tfw:LONDON sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_train sfi:type ttl:Researcher.
#
# tfw:Post_Ammonia_Fuel_Cells sfi:type czz:Reconversion.
#
# tfw:Volvo_AB sfi:type ttl:Supplier.
#
# tfw:UK sfi:type ttl:Manufacturer.
#
# tfw:Fuel_Cell sfi:type czz:Reconversion.
#
# tfw:a_controlling_agent sfi:type ttl:Supplier.
#
# tfw:reproduction sfi:type czz:Product.
#
# tfw:Green_hydrogen sfi:type ttl:Supplier.
#
# tfw:English sfi:type ttl:Researcher.
#
# tfw:Spanish_utility_Iberdrola sfi:type ttl:Supplier.
#
# tfw:Bloom sfi:type ttl:Supplier.
#
# tfw:hydrogen sfi:type ttl:Manufacturer.
#
# tfw:solid_oxide_fuel_cells sfi:type ttl:inTesting.
#
# tfw:STT sfi:type ttl:Manufacturer.
#
# tfw:Blue_World_Technologies sfi:type ttl:inTesting.
#
# tfw:fuel_cell sfi:type ttl:inTesting.
#
# tfw:Green_Hydrogen sfi:type czz:Conversion.
#
# tfw:Matthias_Jurytko sfi:type ttl:Researcher.
#
# tfw:Hydrogen_Fuel_Cell_Buses sfi:type czz:Reconversion.
#
# tfw:prototype sfi:type ttl:inTesting.
#
# tfw:Beijing sfi:type ttl:Researcher.
#
# tfw:air_conditioning sfi:type ttl:inProduction.
#
# tfw:European_Clean_Hydrogen_Alliance sfi:type ttl:Researcher.
#
# tfw:truck sfi:type czz:Truck.
#
# tfw:Activision sfi:type ttl:Researcher.
#
# tfw:Beijing_Daily sfi:type ttl:Researcher.
#
# tfw:ZeroAvia sfi:type ttl:Manufacturer.
#
# yzr:mahle_opens_new_test_center_in_germany_for_fuel_cells sfi:type bbq:BibliographicResource.
#
# tfw:Lithium_Ion_Battery_and_Fuel_Cell sfi:type czz:Battery.
#
# tfw:small_aircraft sfi:type czz:Aircraft.
#
# tfw:The_Korea_Institute_of_Science_and_Technology sfi:type czz:Product.
#
# tfw:Industry_News sfi:type ttl:Supplier.
#
# tfw:Toyota_Motor_Europe sfi:type ttl:Supplier.
#
# tfw:hydrogen_fuel_cells sfi:type czz:Product.
#
# tfw:Alfa_Laval sfi:type ttl:Researcher.
#
# tfw:%27green%27_hydrogen sfi:type ttl:inResearch.
#
# tfw:The_Clean_Hydrogen_Alliance sfi:type ttl:Supplier.
#
# tfw:transportation_in sfi:type czz:Mobile.
#
# tfw:fossil_fuel sfi:type ttl:inProduction.
#
# tfw:renewable_energy sfi:type ttl:inResearch.
#
# tfw:Blue_World_Technologies sfi:type ttl:Supplier.
#
# tfw:Fuel_Cell_Polarized sfi:type ttl:inProduction.
#
# tfw:Hydrogen_fuel_cells sfi:type ttl:Manufacturer.
#
# tfw:discovery sfi:type czz:Intangible.
#
# tfw:Post_Ammonia_Fuel_Cells sfi:type czz:Product.
#
# tfw:The_European_Union sfi:type ttl:Researcher.
#
# tfw:hydrogen_production sfi:type ttl:Manufacturer.
#
# tfw:Australia sfi:type ttl:Manufacturer.
#
# tfw:Hydrogen_NEXO_Vehicle_POSCO sfi:type ttl:Customer.
#
# tfw:project sfi:type zpq:Project.
#
# tfw:high_pressure_hydrogen_tanks sfi:type ttl:inProduction.
#
# tfw:CEC sfi:type ttl:Supplier.
#
# tfw:Fuel_Cell sfi:type czz:Product.
#
# tfw:Fukushima sfi:type ttl:Supplier.
#
# byd:talgo%E2%80%99s_hydrogen_train_will_be_ready_2023 sfi:type bbq:BibliographicResource.
#
# tfw:zero_emission_technology sfi:type ttl:inTesting.
#
# tfw:Antiseptic_Mouth_Wash sfi:type ttl:Researcher.
#
# tfw:IEEE_Spectrum sfi:type ttl:Researcher.
#
# tfw:product sfi:type ttl:inResearch.
#
# tfw:hydrogen_technology sfi:type ttl:Manufacturer.
#
# tfw:Stellantis sfi:type ttl:Supplier.
#
# tfw:fuel_cell_system sfi:type czz:Reconversion.
#
# tfw:the_Suiso_Frontier sfi:type ttl:inResearch.
#
# tfw:High_Pressure_Hydrogen_Tanks sfi:type ttl:Supplier.
#
# tfw:Daimler_Truck_AG sfi:type ttl:Manufacturer.
#
# tfw:GlobeNewswire_Advanced_TORONTO sfi:type ttl:Customer.
#
# tfw:Lhyfe sfi:type ttl:Customer.
#
# tfw:San_Francisco_Clean_Cities_Coalition sfi:type ttl:Supplier.
#
# tfw:Powertrain_Daimler_Trucks_division sfi:type czz:Truck.
#
# tfw:Renewable_hydrogen sfi:type ttl:inProduction.
#
# tfw:a_new_technology sfi:type czz:Product.
#
# tfw:catalyst sfi:type ttl:inTesting.
#
# tfw:new_hydrogen_vehicle sfi:type ttl:inProduction.
#
# tfw:Kawasaki_Heavy_Industries sfi:type ttl:Manufacturer.
#
# tfw:Ammonia sfi:type ttl:inTesting.
#
# tfw:Flake sfi:type ttl:inProduction.
#
# tfw:Project sfi:type zpq:Project.
#
# tfw:European_Union sfi:type ttl:Supplier.
#
# tfw:Ref__XX sfi:type ttl:inResearch.
#
# tfw:mouth_wash sfi:type ttl:inResearch.
#
# tfw:hydrogen_fuel_%2C sfi:type ttl:inResearch.
#
# tfw:Twitter sfi:type ttl:inProduction.
#
# tfw:batteries sfi:type ttl:inProduction.
#
# tfw:fuel_cells_are sfi:type czz:Reconversion.
#
# tfw:GazelEnergie_Join_Forces sfi:type ttl:inResearch.
#
# tfw:H2 sfi:type ttl:inProduction.
#
# tfw:Wind_Hunter_Project sfi:type ttl:inTesting.
#
# tfw:hydrogen_fuel_cell sfi:type ttl:inTesting.
#
# tfw:UAM%2C_automobiles%2C_vessels_and_trains sfi:type czz:Car.
#
# tfw:Toyoda_Gosei sfi:type ttl:Researcher.
#
# tfw:Hydrogen_Infrastructure sfi:type ttl:Customer.
#
# tfw:hydrogen_fuel_%2C sfi:type ttl:Researcher.
#
# tfw:Dedicated_Fuel_Cell_System sfi:type czz:Reconversion.
#
# tfw:hydrogen_trains sfi:type ttl:inResearch.
#
# tfw:produce sfi:type ttl:Manufacturer.
#
# tfw:methanol sfi:type ttl:inProduction.
#
# tfw:More_Deals_%26_Coupons sfi:type czz:Car.
#
# tfw:Fuel_Cells sfi:type ttl:inProduction.
#
# tfw:Motomachi_Plant sfi:type ttl:inProduction.
#
# tfw:fuel_cell_system sfi:type czz:Product.
#
# tfw:Mn_Ru sfi:type ttl:inResearch.
#
# tfw:Channel_10 sfi:type ttl:Researcher.
#
# tfw:renewable_and_low_carbon_hydrogen sfi:type czz:Car.
#
# tfw:hydrogen_fuel_cell sfi:type ttl:Supplier.
#
# tfw:fuel_and sfi:type ttl:inProduction.
#
# tfw:venture sfi:type zpq:Project.
#
# tfw:H20 sfi:type ttl:inProduction.
#
# tfw:air_conditioning sfi:type ttl:inTesting.
#
# tfw:Vanguard sfi:type ttl:Supplier.
#
# tfw:testing_and_vaccination_strategy sfi:type ttl:inProduction.
#
# tfw:the_%E2%80%9C_European_Clean_Hydrogen_Alliance sfi:type ttl:inProduction.
#
# tfw:Toyota_Motor_Europe sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_fueling_stations sfi:type ttl:Supplier.
#
# esi:1551 sfi:type bbq:BibliographicResource.
#
# tfw:TME sfi:type ttl:Customer.
#
# tfw:hydrogen_in sfi:type ttl:Manufacturer.
#
# tfw:Japan sfi:type ttl:Supplier.
#
# tfw:fuel_cells_are sfi:type czz:Product.
#
# tfw:hydrogen_train sfi:type ttl:Supplier.
#
# tfw:hydrogen_vehicle_fleet sfi:type czz:Road.
#
# tfw:fossil_fuel sfi:type ttl:inTesting.
#
# tfw:ECH2A sfi:type ttl:Researcher.
#
# tfw:hydrogen_projects sfi:type ttl:inResearch.
#
# tfw:Amazon sfi:type ttl:Customer.
#
# tfw:Cariba_Heine sfi:type ttl:Supplier.
#
# tfw:solid_oxide_fuel_cells sfi:type ttl:Manufacturer.
#
# tfw:Blue_World_Technologies sfi:type ttl:Manufacturer.
#
# tfw:DNI sfi:type ttl:Manufacturer.
#
# tfw:Fuel_Cell_Polarized sfi:type ttl:inTesting.
#
# acx:NearFuturePropulsionExtras_0_5_3 sfi:type bbq:BibliographicResource.
#
# tfw:Oakley_Men sfi:type ttl:Customer.
#
# ind: sfi:type bbq:BibliographicResource.
#
# tfw:Mitsui_O_S_K__Lines sfi:type ttl:Customer.
#
# tfw:OCTA sfi:type ttl:Researcher.
#
# tfw:Dedicated_Fuel_Cell_System sfi:type czz:Product.
#
# tfw:SoCalGas sfi:type ttl:Customer.
#
# tfw:University_of_Mannheim sfi:type czz:Research.
#
# tfw:high_pressure_hydrogen_tanks sfi:type ttl:inTesting.
#
# tfw:Hydrogen_and_Fuel_Cell_Technologies sfi:type ttl:inResearch.
#
# tfw:Position_yourself_for_advantage sfi:type czz:RegionalTruck.
#
# tfw:Alliance sfi:type ttl:Customer.
#
# tfw:Green_Hydrogen sfi:type ttl:Customer.
#
# tfw:Video sfi:type ttl:inResearch.
#
# tfw:Beijing sfi:type ttl:Supplier.
#
# tfw:%27green%27_hydrogen sfi:type ttl:inTesting.
#
# tfw:European_Clean_Hydrogen_Alliance sfi:type ttl:Supplier.
#
# tfw:ZEV sfi:type czz:Road.
#
# tfw:hydrogen_transportation sfi:type ttl:inResearch.
#
# tfw:Beijing_Daily sfi:type ttl:Supplier.
#
# tfw:Germany sfi:type ttl:Manufacturer.
#
# tfw:Powertrain_Daimler_Trucks_division sfi:type czz:Train.
#
# tfw:FuelCellsWorks sfi:type ttl:inProduction.
#
# tfw:Reuters sfi:type ttl:Customer.
#
# tfw:hydrogen_projects sfi:type ttl:inProduction.
#
# tfw:ketoximes sfi:type ttl:inResearch.
#
# tfw:Industry_News sfi:type ttl:Customer.
#
# tfw:Renewable_hydrogen sfi:type ttl:inTesting.
#
# tfw:technology sfi:type ttl:Manufacturer.
#
# tfw:Wind_Hunter_Project sfi:type zpq:Project.
#
# tfw:a_fuel_cell_electric sfi:type czz:Reconversion.
#
# dqy:Podcast_Dr_Josef_Kallo_On_Fuel_Cell_Progress_226201_1_html sfi:type bbq:BibliographicResource.
#
# tfw:Hydrogen_Evolution sfi:type czz:Road.
#
# vur:chinas_capital_envisages_10_000_fuel_cell_vehicles_by_2025_2411012 sfi:type bbq:BibliographicResource.
#
# tfw:Hyundai_Motor_Group sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_train sfi:type czz:Train.
#
# tfw:European_Union sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_fuel_cell_system sfi:type ttl:inProduction.
#
# tfw:local_transportation sfi:type czz:Mobile.
#
# tfw:SOFC4Maritime sfi:type ttl:Customer.
#
# tfw:hydrogen_tank sfi:type ttl:inResearch.
#
# tfw:Inabe_Plant sfi:type ttl:Customer.
#
# tfw:The_European_Union sfi:type ttl:Supplier.
#
# tfw:Twitter sfi:type ttl:inTesting.
#
# tfw:fuel_cell_electric_vehicles sfi:type ttl:inResearch.
#
# tfw:ketoximes sfi:type ttl:inProduction.
#
# tfw:hydrogen sfi:type ttl:Researcher.
#
# tfw:transportation_is sfi:type czz:Mobile.
#
# uzc:energy_department_announces_climate_action_champion_city_san_francisco_embracing sfi:type bbq:BibliographicResource.
#
# tfw:AUVSI sfi:type ttl:Customer.
#
# tfw:Breakthrough_Energy_Ventures sfi:type ttl:Customer.
#
# tfw:H2 sfi:type ttl:inTesting.
#
# tfw:Nafion sfi:type ttl:Manufacturer.
#
# tfw:The_Korea_Institute_of_Science_and_Technology sfi:type ttl:Customer.
#
# tfw:Toyota sfi:type ttl:inResearch.
#
# tfw:hydrogen_fuel_cells sfi:type ttl:Customer.
#
# tfw:Antiseptic_Mouth_Wash sfi:type ttl:Supplier.
#
# tfw:China sfi:type ttl:Manufacturer.
#
# tfw:Hydrogen_Peroxide sfi:type ttl:inResearch.
#
# tfw:Featured_Company_Featured_Company_DNI_Metals_Inc sfi:type jgy:RegisteredOrganization.
#
# tfw:Toyota sfi:type ttl:Researcher.
#
# tfw:Orange_County_Transportation_Authority sfi:type ttl:inResearch.
#
# tfw:methanol sfi:type ttl:inTesting.
#
# tfw:mouth_wash sfi:type ttl:inTesting.
#
# tfw:Fuel_Cells sfi:type ttl:inTesting.
#
# tfw:hydrogen_tank sfi:type ttl:inProduction.
#
# tfw:the_plan_that_the_commission_recently_approved sfi:type ttl:inProduction.
#
# tfw:ORR sfi:type ttl:Researcher.
#
# jyx: sfi:type bbq:BibliographicResource.
#
# tfw:hydrogen_and_fuel_cell_technologies sfi:type ttl:inResearch.
#
# tfw:production sfi:type czz:Product.
#
# tfw:a_fuel_cell_electric sfi:type czz:Product.
#
# tfw:fuel_and sfi:type ttl:inTesting.
#
# tfw:Post_Ammonia_Fuel_Cells sfi:type czz:AmmoniaFuelCell.
#
# tfw:Green_Hydrogen sfi:type ttl:inResearch.
#
# tfw:prototype sfi:type czz:Tangible.
#
# pta: sfi:type bbq:BibliographicResource.
#
# tfw:Hydrogen_Fuel_Cell sfi:type ttl:inResearch.
#
# tfw:TME sfi:type ttl:inProduction.
#
# tfw:hydrogen_production sfi:type ttl:Researcher.
#
# tfw:rearview_mirror_car sfi:type czz:Car.
#
# tfw:hydrogen_trains sfi:type ttl:inTesting.
#
# tfw:Fuel_Cell_Business sfi:type ttl:inProduction.
#
# tfw:SoCalGas sfi:type ttl:Researcher.
#
# tfw:methanol_fuel_cell sfi:type ttl:inProduction.
#
# tfw:Volvo_Group sfi:type ttl:Customer.
#
# tfw:Japan sfi:type ttl:Manufacturer.
#
# tfw:Toyota_Motor_Corporation sfi:type ttl:Customer.
#
# tfw:University sfi:type ttl:Customer.
#
# tfw:Hydrogen_Fuel_Cell sfi:type ttl:Researcher.
#
# tfw:Daimler_AG sfi:type ttl:Manufacturer.
#
# tfw:Talgo sfi:type ttl:Manufacturer.
#
# tfw:Green_hydrogen sfi:type ttl:inProduction.
#
# tfw:Daimler_Truck_AG sfi:type ttl:Researcher.
#
# tfw:Reuters sfi:type ttl:Researcher.
#
# tfw:Green_Hydrogen sfi:type ttl:inProduction.
#
# tfw:the_production sfi:type ttl:Supplier.
#
# tfw:Lithium_Ion_Battery_and_Fuel_Cell sfi:type ttl:inProduction.
#
# xrf: sfi:type bbq:BibliographicResource.
#
# tfw:contribute_to_the_development_of_zero_carbon_hydrogen sfi:type czz:Bus.
#
# xgp: sfi:type bbq:BibliographicResource.
#
# tfw:Fortescue_Metals_Group sfi:type ttl:Customer.
#
# tfw:Beiqi_Foton_Motor sfi:type ttl:Researcher.
#
# tfw:next_generation sfi:type ttl:inResearch.
#
# tfw:hydrogen_fuel_cells sfi:type ttl:inResearch.
#
# tfw:application sfi:type czz:Application.
#
# tfw:hydrogen_projects sfi:type ttl:inTesting.
#
# tfw:Hydrogen sfi:type ttl:Customer.
#
# tfw:Inabe_Plant sfi:type ttl:Researcher.
#
# tfw:fuel_cells sfi:type czz:Reconversion.
#
# tfw:AUVSI sfi:type ttl:Researcher.
#
# tfw:green_hydrogen sfi:type czz:Conversion.
#
# tfw:contribute_to_the_development_of_zero_carbon_hydrogen sfi:type czz:Car.
#
# tfw:hydrogen_fuel_cells sfi:type ttl:Researcher.
#
# tfw:methanol_fuel_cell sfi:type czz:EthanolFuelCell.
#
# keu: sfi:type bbq:BibliographicResource.
#
# tfw:Hydrogen_and_Fuel_Cell_Technologies sfi:type czz:Product.
#
# tfw:hydrogen_fuel_cell_system sfi:type ttl:inTesting.
#
# tfw:H2O2 sfi:type ttl:inResearch.
#
# tfw:San_Francisco sfi:type ttl:Researcher.
#
# tfw:produce sfi:type ttl:Researcher.
#
# tfw:GlobeNewswire_Advanced_TORONTO sfi:type ttl:Supplier.
#
# tfw:Lhyfe sfi:type ttl:Supplier.
#
# tfw:green sfi:type ttl:inProduction.
#
# tfw:Fuel_Cell sfi:type ttl:inResearch.
#
# tfw:HyET_Hydrogen sfi:type ttl:Researcher.
#
# tfw:Hydrogen_fuel_cells sfi:type czz:Reconversion.
#
# tfw:ketoximes sfi:type ttl:inTesting.
#
# tfw:Korea_Institute_of_Science_and_Technology sfi:type jgy:RegisteredOrganization.
#
# tfw:hydrogen_projects sfi:type ttl:Supplier.
#
# tfw:Fuel_Cell_System sfi:type ttl:inProduction.
#
# tfw:Mads_Friis_Jensen sfi:type ttl:Researcher.
#
# tfw:Renewable_hydrogen sfi:type ttl:Manufacturer.
#
# tfw:hydrogen_powered_planes sfi:type czz:Aircraft.
#
# sji: sfi:type bbq:BibliographicResource.
#
# tfw:European sfi:type ttl:inProduction.
#
# tfw:hydrogen_bond_donor_scaffolds sfi:type ttl:inResearch.
#
# tfw:Fuel_Cell sfi:type ttl:Researcher.
#
# tfw:a_new_technology sfi:type ttl:inResearch.
#
# tfw:Activision sfi:type ttl:Customer.
#
# tfw:hydrogen_trains sfi:type czz:Train.
#
# tfw:carandbike_com sfi:type czz:Car.
#
# tfw:truck sfi:type ttl:inProduction.
#
# tfw:hydrogen_tank sfi:type ttl:inTesting.
#
# tfw:Volvo_Group sfi:type ttl:Researcher.
#
# tfw:Hydrogen_Infrastructure sfi:type ttl:Supplier.
#
# tfw:DOI sfi:type ttl:Manufacturer.
#
# tfw:nano_metal_catalyst sfi:type ttl:inTesting.
#
# tfw:fuel_cells sfi:type czz:Product.
#
# tfw:Hydrogen_plane sfi:type czz:Aircraft.
#
# nrw: sfi:type bbq:BibliographicResource.
#
# tfw:Masamichi_Okada sfi:type ttl:Supplier.
#
# tfw:TME sfi:type ttl:inTesting.
#
# tfw:Fuel_Cell_Technologies sfi:type ttl:inProduction.
#
# tfw:Orange_County_Transportation_Authority sfi:type ttl:inTesting.
#
# tfw:Tuesday sfi:type ttl:inResearch.
#
# tfw:hydrogen_carrier sfi:type czz:Car.
#
# tfw:Hydrogen sfi:type ttl:inResearch.
#
# tfw:Hydrogen_fuel_cells sfi:type czz:Product.
#
# tfw:Fortescue_Metals_Group sfi:type ttl:Researcher.
#
# tfw:Volvo sfi:type ttl:Researcher.
#
# tfw:hydrogen_production sfi:type czz:Product.
#
# qai: sfi:type bbq:BibliographicResource.
#
# tfw:University_of_Mannheim sfi:type ttl:Researcher.
#
# tfw:fuel_cell_system sfi:type ttl:inResearch.
#
# tfw:Fuel_Cell_Business sfi:type czz:Reconversion.
#
# tfw:Zhao sfi:type ttl:Customer.
#
# tfw:technology sfi:type ttl:Researcher.
#
# tfw:Green_Hydrogen sfi:type ttl:inTesting.
#
# tfw:SOFC4Maritime sfi:type czz:SolidOxideFuelCell.
#
# tfw:Lithium_Ion_Battery_and_Fuel_Cell sfi:type ttl:inTesting.
#
# tfw:TME sfi:type ttl:Supplier.
#
# tfw:hydrogen_technology sfi:type czz:Product.
#
# tfw:Hydrogen_Peroxide sfi:type ttl:Supplier.
#
# tfw:Town_council sfi:type ttl:Supplier.
#
# tfw:fuel_cell_system sfi:type ttl:Researcher.
#
# tfw:Hydrogen sfi:type ttl:inProduction.
#
# tfw:Amazon sfi:type ttl:Supplier.
#
# tfw:Spyro_Reignited sfi:type ttl:inResearch.
#
# ots: sfi:type bbq:BibliographicResource.
#
# dlc:_Friday sfi:type ttl:Manufacturer.
#
# tfw:Oakley_Men sfi:type ttl:Supplier.
#
# tfw:Oakley_Men%27s_Sunglasses sfi:type ttl:Customer.
#
# tfw:Fuel_cell_power_pack sfi:type czz:Reconversion.
#
# tfw:Japan sfi:type ttl:inProduction.
#
# tfw:German sfi:type ttl:inProduction.
#
# tfw:Mitsui_O_S_K__Lines sfi:type ttl:Supplier.
#
# tfw:hydrogen_train sfi:type ttl:inProduction.
#
# tfw:fuel_cells_are sfi:type ttl:inResearch.
#
# tfw:SoCalGas sfi:type ttl:Supplier.
#
# tfw:CAF sfi:type ttl:Researcher.
#
# tfw:minimizing_carbon_dioxide_emissions sfi:type czz:Car.
#
# tfw:Toyoda_Gosei sfi:type ttl:Customer.
#
# tfw:catalyst sfi:type ttl:Researcher.
#
# tfw:fuel_cell_vehicles sfi:type czz:Product.
#
# tfw:Green_Hydrogen sfi:type ttl:Supplier.
#
# tfw:fossil_fuel sfi:type czz:FossilFuel.
#
# tfw:Dedicated_Fuel_Cell_System sfi:type ttl:inResearch.
#
# tfw:decarbonising_road_transport sfi:type czz:Mobile.
#
# tfw:fuel_cell_modules sfi:type czz:Reconversion.
#
# tfw:CD_Projekt_Red sfi:type ttl:Customer.
#
# tfw:Reuters sfi:type ttl:Supplier.
#
# tfw:Climate_Pledge_Fund sfi:type ttl:inResearch.
#
# tfw:GlobeNewswire_Advanced_TORONTO sfi:type ttl:Manufacturer.
#
# tfw:fuel_cell sfi:type czz:Reconversion.
#
# tfw:Daimler_Truck_Fuel_Cell sfi:type ttl:Researcher.
#
# tfw:solid_oxide_fuel_cells sfi:type czz:Reconversion.
#
# tfw:Hyundai sfi:type ttl:Manufacturer.
#
# tfw:the_production sfi:type ttl:Customer.
#
# tfw:Channel_10 sfi:type ttl:Customer.
#
# tfw:vehicles sfi:type ttl:Researcher.
#
# tfw:hydrogen_projects sfi:type ttl:Manufacturer.
#
# tfw:European_Clean_Hydrogen_Alliance sfi:type ttl:inProduction.
#
# tfw:FuelCellsWorks sfi:type ttl:Manufacturer.
#
# tfw:Fuel_Cell_System sfi:type ttl:inTesting.
#
# tfw:proton_conducting_polymers sfi:type ttl:Manufacturer.
#
# tfw:zero_emission_commercial_aircraft sfi:type czz:Aircraft.
#
# tfw:Southeast sfi:type ttl:inProduction.
#
# tfw:natural_gas sfi:type ttl:inResearch.
#
# tfw:products sfi:type czz:Product.
#
# tfw:ACWA_Power sfi:type ttl:Manufacturer.
#
# tfw:SOFC4Maritime sfi:type ttl:Supplier.
#
# tfw:ALICE sfi:type ttl:Supplier.
#
# tfw:Inabe_Plant sfi:type ttl:Supplier.
#
# tfw:H2O2 sfi:type ttl:inTesting.
#
# tfw:Talgo_Vittal_One sfi:type ttl:Researcher.
#
# tfw:benchmark_solutions sfi:type ttl:inTesting.
#
# tfw:today sfi:type ttl:inProduction.
#
# tfw:hydrogen_fuel_cell_system sfi:type ttl:Manufacturer.
#
# mue: sfi:type bbq:BibliographicResource.
#
# tfw:Climate_Pledge_Fund sfi:type ttl:inProduction.
#
# tfw:AUVSI sfi:type ttl:Supplier.
#
# tfw:Fuel_cell_power_pack sfi:type czz:Product.
#
# tfw:journal_articles%2C_books_or_book_chapters sfi:type ttl:inProduction.
#
# tfw:%27green%27_hydrogen sfi:type ttl:inProduction.
#
# tfw:renewable_energy sfi:type ttl:inProduction.
#
# tfw:Petrochemical_Corporation sfi:type ttl:Supplier.
#
# tfw:San_Francisco sfi:type ttl:Supplier.
#
# tfw:a_%C2%A32_million_government_fund sfi:type ttl:inProduction.
#
# tfw:Hydrogen_Fuel_Cell_Buses sfi:type czz:Product.
#
# tfw:OCTA sfi:type ttl:Customer.
#
# tfw:HyET_Hydrogen sfi:type ttl:Supplier.
#
# tfw:Zhao sfi:type ttl:Researcher.
#
# tfw:fuel_cell_modules sfi:type czz:Product.
#
# tfw:Toyoda_Gosei_Co__%2C_Ltd sfi:type ttl:Manufacturer.
#
# tfw:Daimler_Truck_Fuel_Cell_GmbH_%26_Co_KG sfi:type ttl:Manufacturer.
#
# tfw:solid_oxide_fuel_cells sfi:type czz:Product.
#
# tfw:Lithium_Ion_Battery_and_Fuel_Cell sfi:type czz:LithiumBattery.
#
# tfw:Blue_World_Technologies sfi:type czz:Product.
#
# ryn: sfi:type bbq:BibliographicResource.
#
# tfw:fuel_cell sfi:type czz:Product.
#
# tfw:solar_energy sfi:type ttl:Researcher.
#
# vbj: sfi:type bbq:BibliographicResource.
#
# tfw:aircraft sfi:type ttl:Manufacturer.
#
# tfw:product sfi:type ttl:inProduction.
#
# gxt: sfi:type bbq:BibliographicResource.
#
# tfw:Tokyo_and_the_Fukushima_Prefecture sfi:type ttl:Researcher.

# %% [markdown]
# ### You can now simply copy the contents of final_output.txt to a Turtle file in VS Code. I have called it Hydrogen_Refined_Graph.ttl
